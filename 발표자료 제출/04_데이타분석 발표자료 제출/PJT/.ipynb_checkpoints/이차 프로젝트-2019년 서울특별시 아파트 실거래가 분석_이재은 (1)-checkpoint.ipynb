# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import ConnectionPatch

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %% [markdown]
# ## 1. 법정동 코드 가공

# %%
locCode = pd.read_excel('../data/법정동코드.xlsx')
locCode.head()
# Out:
#         법정동코드    시도명 시군구명 읍면동명  동리명      생성일자  말소일자
# 0  1100000000  서울특별시  NaN  NaN  NaN  19880423   NaN
# 1  1111000000  서울특별시  종로구  NaN  NaN  19880423   NaN
# 2  1111010100  서울특별시  종로구  청운동  NaN  19880423   NaN
# 3  1111010200  서울특별시  종로구  신교동  NaN  19880423   NaN
# 4  1111010300  서울특별시  종로구  궁정동  NaN  19880423   NaN

# %%
seoul = locCode[locCode['시도명'] == '서울특별시']
seoul['지역코드']= seoul['법정동코드'].astype(str).str.slice(start=0,stop=5)
seoul = seoul.loc[:,['시군구명','지역코드']]
seoul = seoul.drop_duplicates(['지역코드'], keep='last')
seoul.reset_index(inplace=True)
seoul.drop('index',axis=1,inplace=True)
seoul.drop(0,inplace=True)
seoul['지역코드'] = np.int64(seoul['지역코드'])
# Out:
# C:\lje\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 1 to 25
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구명    25 non-null     object
#  1   지역코드    25 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 600.0+ bytes

# %% [markdown]
# ## 2. 실거래가 데이터 가공

# %%
apt = pd.read_csv('../data/2019년 서울 아파트 실거래가.csv', encoding="cp949")
apt.head()
# Out:
#    건축년도  거래년도  거래월  거래일자   법정동        거래금액                  아파트이름    전용면적  \
# 0  2008  2019    1     7   사직동     105,000  광화문풍림스페이스본(101동~105동)   97.61
# 1  2008  2019    1    11   사직동     162,000       광화문풍림스페이스본(106동)  163.33
# 2  2008  2019    1    19   사직동     119,000  광화문풍림스페이스본(101동~105동)  131.44
# 3  2008  2019    1    30   사직동     119,000  광화문풍림스페이스본(101동~105동)  147.31
# 4  2004  2019    1    25   내수동     160,000              경희궁의아침4단지  150.48
#
#     지역코드   층   지번
# 0  11110  10    9
# 1  11110  11  9-1
# 2  11110  13    9
# 3  11110   1    9
# 4  11110  14   73

# %%
apt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68864 entries, 0 to 68863
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   건축년도    68864 non-null  int64
#  1   거래년도    68864 non-null  int64
#  2   거래월     68864 non-null  int64
#  3   거래일자    68864 non-null  int64
#  4   법정동     68864 non-null  object
#  5   거래금액    68864 non-null  object
#  6   아파트이름   68864 non-null  object
#  7   전용면적    68864 non-null  float64
#  8   지역코드    68864 non-null  int64
#  9   층       68864 non-null  int64
#  10  지번      68864 non-null  object
# dtypes: float64(1), int64(6), object(4)
# memory usage: 5.8+ MB

# %%
# 거래금액 컬럼의 콤마(,) 제거 후 데이터 타입 변경..int64로
apt['거래금액'] = apt['거래금액'].str.replace(",","").astype(int)
apt['거래금액'] = np.int64(apt['거래금액'])
apt
# Out:
#        건축년도  거래년도  거래월  거래일자   법정동    거래금액                  아파트이름    전용면적  \
# 0      2008  2019    1     7   사직동  105000  광화문풍림스페이스본(101동~105동)   97.61
# 1      2008  2019    1    11   사직동  162000       광화문풍림스페이스본(106동)  163.33
# 2      2008  2019    1    19   사직동  119000  광화문풍림스페이스본(101동~105동)  131.44
# 3      2008  2019    1    30   사직동  119000  광화문풍림스페이스본(101동~105동)  147.31
# 4      2004  2019    1    25   내수동  160000              경희궁의아침4단지  150.48
# ...     ...   ...  ...   ...   ...     ...                    ...     ...
# 68859  2013  2019   12    30   천호동   14500                   하이브2   13.50
# 68860  2009  2019   12     7   강일동   79750             강일리버파크10단지   84.53
# 68861  2009  2019   12     9   강일동   77800              강일리버파크2단지   84.74
# 68862  2009  2019   12    25   강일동   80000              강일리버파크7단지   84.83
# 68863  2009  2019   12    30   강일동   85000             강일리버파크10단지  114.81
#
#         지역코드   층      지번
# 0      11110  10       9
# 1      11110  11     9-1
# 2      11110  13       9
# 3      11110   1       9
# 4      11110  14      73
# ...      ...  ..     ...
# 68859  11740  11  164-70
# 68860  11740   9     695
# 68861  11740   4     668
# 68862  11740   3     686
# 68863  11740  14     695
#
# [68864 rows x 11 columns]

# %%
# 전용면적(제곱미터)를 평으로 변환(나누기 3.306)하여 전용면적(평) 컬럼 생성 후 소숫점 둘쨰자리까지 표시합니다.
apt['전용면적(평)'] = round(apt['전용면적']/3.306,2)
apt
# Out:
#        건축년도  거래년도  거래월  거래일자   법정동    거래금액                  아파트이름    전용면적  \
# 0      2008  2019    1     7   사직동  105000  광화문풍림스페이스본(101동~105동)   97.61
# 1      2008  2019    1    11   사직동  162000       광화문풍림스페이스본(106동)  163.33
# 2      2008  2019    1    19   사직동  119000  광화문풍림스페이스본(101동~105동)  131.44
# 3      2008  2019    1    30   사직동  119000  광화문풍림스페이스본(101동~105동)  147.31
# 4      2004  2019    1    25   내수동  160000              경희궁의아침4단지  150.48
# ...     ...   ...  ...   ...   ...     ...                    ...     ...
# 68859  2013  2019   12    30   천호동   14500                   하이브2   13.50
# 68860  2009  2019   12     7   강일동   79750             강일리버파크10단지   84.53
# 68861  2009  2019   12     9   강일동   77800              강일리버파크2단지   84.74
# 68862  2009  2019   12    25   강일동   80000              강일리버파크7단지   84.83
# 68863  2009  2019   12    30   강일동   85000             강일리버파크10단지  114.81
#
#         지역코드   층      지번  전용면적(평)
# 0      11110  10       9    29.53
# 1      11110  11     9-1    49.40
# 2      11110  13       9    39.76
# 3      11110   1       9    44.56
# 4      11110  14      73    45.52
# ...      ...  ..     ...      ...
# 68859  11740  11  164-70     4.08
# 68860  11740   9     695    25.57
# 68861  11740   4     668    25.63
# 68862  11740   3     686    25.66
# 68863  11740  14     695    34.73
#
# [68864 rows x 12 columns]

# %%
# 전용면적을 범주화 하기 위해 전용면적(평) 컬럼을 정수형으로 바꾼 새로운 컬럼을 생성합니다.
# 컬럼명 전용면적2(평)
apt['전용면적(평)2'] = apt['전용면적(평)'].astype(int)
apt
# Out:
#        건축년도  거래년도  거래월  거래일자   법정동    거래금액                  아파트이름    전용면적  \
# 0      2008  2019    1     7   사직동  105000  광화문풍림스페이스본(101동~105동)   97.61
# 1      2008  2019    1    11   사직동  162000       광화문풍림스페이스본(106동)  163.33
# 2      2008  2019    1    19   사직동  119000  광화문풍림스페이스본(101동~105동)  131.44
# 3      2008  2019    1    30   사직동  119000  광화문풍림스페이스본(101동~105동)  147.31
# 4      2004  2019    1    25   내수동  160000              경희궁의아침4단지  150.48
# ...     ...   ...  ...   ...   ...     ...                    ...     ...
# 68859  2013  2019   12    30   천호동   14500                   하이브2   13.50
# 68860  2009  2019   12     7   강일동   79750             강일리버파크10단지   84.53
# 68861  2009  2019   12     9   강일동   77800              강일리버파크2단지   84.74
# 68862  2009  2019   12    25   강일동   80000              강일리버파크7단지   84.83
# 68863  2009  2019   12    30   강일동   85000             강일리버파크10단지  114.81
#
#         지역코드   층      지번  전용면적(평)  전용면적(평)2
# 0      11110  10       9    29.53        29
# 1      11110  11     9-1    49.40        49
# 2      11110  13       9    39.76        39
# 3      11110   1       9    44.56        44
# 4      11110  14      73    45.52        45
# ...      ...  ..     ...      ...       ...
# 68859  11740  11  164-70     4.08         4
# 68860  11740   9     695    25.57        25
# 68861  11740   4     668    25.63        25
# 68862  11740   3     686    25.66        25
# 68863  11740  14     695    34.73        34
#
# [68864 rows x 13 columns]

# %%
# 전용면적을 범주화 합니다.
# 컬럼명은 전용면적(평)3
bins=np.arange(0,86,5)
bins
apt['전용면적(평)3'] = pd.cut(apt['전용면적(평)2'], bins)
apt.head()
# Out:
#    건축년도  거래년도  거래월  거래일자   법정동    거래금액                  아파트이름    전용면적   지역코드  \
# 0  2008  2019    1     7   사직동  105000  광화문풍림스페이스본(101동~105동)   97.61  11110
# 1  2008  2019    1    11   사직동  162000       광화문풍림스페이스본(106동)  163.33  11110
# 2  2008  2019    1    19   사직동  119000  광화문풍림스페이스본(101동~105동)  131.44  11110
# 3  2008  2019    1    30   사직동  119000  광화문풍림스페이스본(101동~105동)  147.31  11110
# 4  2004  2019    1    25   내수동  160000              경희궁의아침4단지  150.48  11110
#
#     층   지번  전용면적(평)  전용면적(평)2  전용면적(평)3
# 0  10    9    29.53        29  (25, 30]
# 1  11  9-1    49.40        49  (45, 50]
# 2  13    9    39.76        39  (35, 40]
# 3   1    9    44.56        44  (40, 45]
# 4  14   73    45.52        45  (40, 45]

# %%
# 범주화된 전용면적의 고유값을 확인합니다.
apt['전용면적(평)3'].unique()
# Out:
# [(25, 30], (45, 50], (35, 40], (40, 45], (0, 5], ..., (65, 70], (55, 60], (60, 65], (80, 85], (75, 80]]
# Length: 17
# Categories (17, interval[int64]): [(0, 5] < (5, 10] < (10, 15] < (15, 20] ... (65, 70] < (70, 75] < (75, 80] < (80, 85]]

# %% [markdown]
# ## 3. 데이타 프레임 병합

# %%
fin = pd.merge(apt, seoul, on='지역코드', how='inner')
fin
# Out:
#        건축년도  거래년도  거래월  거래일자   법정동    거래금액                  아파트이름    전용면적  \
# 0      2008  2019    1     7   사직동  105000  광화문풍림스페이스본(101동~105동)   97.61
# 1      2008  2019    1    11   사직동  162000       광화문풍림스페이스본(106동)  163.33
# 2      2008  2019    1    19   사직동  119000  광화문풍림스페이스본(101동~105동)  131.44
# 3      2008  2019    1    30   사직동  119000  광화문풍림스페이스본(101동~105동)  147.31
# 4      2004  2019    1    25   내수동  160000              경희궁의아침4단지  150.48
# ...     ...   ...  ...   ...   ...     ...                    ...     ...
# 68859  2013  2019   12    30   천호동   14500                   하이브2   13.50
# 68860  2009  2019   12     7   강일동   79750             강일리버파크10단지   84.53
# 68861  2009  2019   12     9   강일동   77800              강일리버파크2단지   84.74
# 68862  2009  2019   12    25   강일동   80000              강일리버파크7단지   84.83
# 68863  2009  2019   12    30   강일동   85000             강일리버파크10단지  114.81
#
#         지역코드   층      지번  전용면적(평)  전용면적(평)2  전용면적(평)3 시군구명
# 0      11110  10       9    29.53        29  (25, 30]  종로구
# 1      11110  11     9-1    49.40        49  (45, 50]  종로구
# 2      11110  13       9    39.76        39  (35, 40]  종로구
# 3      11110   1       9    44.56        44  (40, 45]  종로구
# 4      11110  14      73    45.52        45  (40, 45]  종로구
# ...      ...  ..     ...      ...       ...       ...  ...
# 68859  11740  11  164-70     4.08         4    (0, 5]  강동구
# 68860  11740   9     695    25.57        25  (20, 25]  강동구
# 68861  11740   4     668    25.63        25  (20, 25]  강동구
# 68862  11740   3     686    25.66        25  (20, 25]  강동구
# 68863  11740  14     695    34.73        34  (30, 35]  강동구
#
# [68864 rows x 15 columns]

# %% [markdown]
# ## 4. 데이타 분석

# %% [markdown]
# #### 아파트 평단가

# %% [markdown]
# #### 구별 평단가

# %%
by_Area.pivot_table(values='평단가',index='시군구명',aggfunc='mean').sort_values(by='평단가',ascending=False)
# Out:
#               평단가
# 시군구명
# 강남구   6794.741483
# 서초구   5800.942654
# 용산구   4865.873004
# 송파구   4767.803892
# 성동구   4116.361446
# 마포구   4044.100229
# 광진구   3641.106724
# 동작구   3527.526229
# 영등포구  3427.267758
# 양천구   3416.527577
# 중구    3378.514223
# 종로구   3340.744308
# 강동구   3328.757528
# 서대문구  3058.548401
# 강서구   2794.887150
# 동대문구  2769.234263
# 성북구   2532.974885
# 관악구   2500.308741
# 은평구   2391.475082
# 구로구   2334.740315
# 노원구   2312.904326
# 중랑구   2178.685675
# 강북구   2126.614094
# 금천구   2045.817039
# 도봉구   1942.452976

# %%
by_Area.pivot_table(values='평단가',index='시군구명',aggfunc='mean').sort_values(by='평단가',ascending=False).plot(kind='barh')
plt.show()

# %% [markdown]
# #### 시기별 평단가

# %%
by_Area.groupby(by='거래월')[['평단가']].mean()
# Out:
#              평단가
# 거래월
# 1    2748.562065
# 2    2817.138239
# 3    2979.525275
# 4    3241.732960
# 5    3536.735214
# 6    3630.964430
# 7    3575.552240
# 8    3388.014232
# 9    3561.092415
# 10   3526.306509
# 11   3491.867658
# 12   3280.164919

# %%
by_Area.groupby(by='거래월')[['평단가']].mean().plot(grid=True)
plt.show()

# %% [markdown]
# #### 층수별 평단가

# %%
#층수별 평단가
by_Area.pivot_table(values='평단가',index='층',aggfunc='mean')
# Out:
#              평단가
# 층
# -2   7590.500000
# -1   3634.062500
#  1   3292.325491
#  2   3233.218211
#  3   3293.155058
# ..           ...
#  61  5306.000000
#  62  6055.000000
#  65  4186.000000
#  66  5252.333333
#  67  5187.000000
#
# [65 rows x 1 columns]

# %%
by_Area.pivot_table(values='평단가',index='층',aggfunc='mean').plot()
plt.show()

# %% [markdown]
# #### 건축년도별 평단가

# %%
#건축년도 평단가
by_Area.pivot_table(values='평단가',index='건축년도',aggfunc='mean').sort_values(by='평단가',ascending=False)
# Out:
#               평단가
# 건축년도
# 1982  8608.279176
# 1978  6626.782609
# 1979  6493.484058
# 1980  6306.350000
# 1977  5684.760479
# 1983  5133.719745
# 1981  5127.502283
# 2016  4925.773562
# 1974  4911.378205
# 1976  4768.832402
# 2008  4701.608610
# 1973  4671.962963
# 2017  4637.129266
# 2015  4476.926740
# 2018  4468.910560
# 1986  4201.591716
# 2009  4114.465241
# 2014  4016.377741
# 2012  3951.092661
# 2011  3933.707654
# 2019  3887.560199
# 1985  3865.914141
# 2007  3757.816000
# 2006  3699.736258
# 1984  3648.910924
# 1987  3569.189452
# 2013  3541.081387
# 1975  3458.433566
# 1971  3389.320312
# 2010  3364.838612
# 1966  3347.200000
# 1992  3255.350272
# 1965  3201.000000
# 2005  3115.717919
# 1988  3063.204459
# 1997  3055.896595
# 1993  3017.536044
# 2001  2976.883893
# 1999  2951.326531
# 1994  2945.231544
# 2000  2863.041088
# 2002  2837.795214
# 2003  2826.293207
# 1998  2747.892508
# 2004  2739.446551
# 1990  2664.423445
# 1970  2647.390244
# 1989  2612.845987
# 1996  2565.889544
# 1995  2563.641657
# 1991  2540.684105
# 1969  2187.400000
# 1968  1707.062500
# 1972  1666.740741
# 1961  1004.000000

# %%
by_Area.pivot_table(values='평단가',index='건축년도',aggfunc='mean').plot()

# %% [markdown]
# #### 서울시 구별 월 평단가
# - 각 구당 월 평단가가 제일 높은 날과, 적은날을 확인하여 비수기와 성수기의 거래가 차이를 가정 할 수 있다.

# %%
disMonth = by_Area.pivot_table(values='평단가',index='거래월',columns='시군구명',aggfunc='mean')
plt.figure(figsize=(12, 10))
sns.lineplot(data=disMonth, palette="tab10", linewidth=2.5,dashes=False)
plt.grid()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.) #레이블 위치변경용
plt.show()

# %% [markdown]
# #### 구별 거래량이 제일 많은 면적의 가격 분포

# %%
sellcount = by_Area.pivot_table(values='거래일자',index=['시군구명',''],columns='전용면적(평)3',aggfunc='count').fillna(0).astype(int)
sellcount
# Out:
# 전용면적(평)3  (0, 5]  (10, 15]  (15, 20]  (20, 25]  (25, 30]  (30, 35]  (35, 40]  \
# 시군구명
# 강남구           22       424       639      1394       253       365       371
# 강동구          219       123      1084      1699       167       279        95
# 강북구           27       100       419       511         1       112        18
# 강서구           50       474       893      1299        83       132       153
# 관악구           76       115       803       737        48       227        28
# 광진구           38        37       453       788        37        32        71
# 구로구           65       351      1134      1333        49       189        76
# 금천구           18       162       465       535        61       114        24
# 노원구          112      2056      1944      1711       130       296       123
# 도봉구           17       610       602      1083        47        62       102
# 동대문구         177        81       774       967        63       213        66
# 동작구           36        96       634      1179        12       245       143
# 마포구           40       166       839      1078        29       229        70
# 서대문구          45        69       792      1056        27       172        80
# 서초구            4       106       427      1122       170       257       241
# 성동구           11        59      1201      1270        32       305        55
# 성북구           24        90      1435      1376        22       405        77
# 송파구           15       406       952      2554       238       298       373
# 양천구            4       372       930      1419       266       261       119
# 영등포구         333       215       773      1032        73       133       123
# 용산구           30        45       336       328        61       127       122
# 은평구           38       118       745       852        67       111        90
# 종로구           65        24       130       195        26        48         8
# 중구            66        29       263       309         8       124        37
# 중랑구           83       268       544       793        82       118        75
#
# 전용면적(평)3  (40, 45]  (45, 50]  (5, 10]  (50, 55]  (55, 60]  (60, 65]  (65, 70]  \
# 시군구명
# 강남구            220       201      238        88        49        37        16
# 강동구             23         4       85         2         2         2         2
# 강북구              2         1        1         0         0         0         0
# 강서구             15        24      190         8         2         0         0
# 관악구             10         0       80         4         0         0         0
# 광진구             62        64        5        19         6         0         9
# 구로구              8        16       71        11         1         0         0
# 금천구              5         1       47         0         0         0         0
# 노원구             37         2      244         3         0         0         0
# 도봉구              9        12      174         0         0         1         0
# 동대문구            12         2      150         5         0         0         0
# 동작구             20        32       15         6         0         0         3
# 마포구             53        13       98         2         6         0         1
# 서대문구            16        14       97         1         0         4         1
# 서초구            159       143      113        37        53        44        26
# 성동구             30         4        3         6         3         1         3
# 성북구             13         6        4         7         5         0         0
# 송파구            275        94      121        45        19         2         2
# 양천구             70       114        4        12        10         6         1
# 영등포구            99        30       30        11        12         2         6
# 용산구             97        37       30        40         7        41        27
# 은평구              9        21       95         1         0         0         0
# 종로구             20        18       25         3         3         2         1
# 중구              29         7       30         6         4         1         0
# 중랑구              3         3      187         0         0         1         0
#
# 전용면적(평)3  (70, 75]  (75, 80]  (80, 85]
# 시군구명
# 강남구             23         2         2
# 강동구              0         0         0
# 강북구              0         0         0
# 강서구              0         0         0
# 관악구              0         0         0
# 광진구              0         0         0
# 구로구              0         0         0
# 금천구              0         0         0
# 노원구              0         0         0
# 도봉구              3         0         0
# 동대문구             0         0         0
# 동작구              0         0         0
# 마포구              0         0         0
# 서대문구             2         0         0
# 서초구             36         8         1
# 성동구              5         0         0
# 성북구              0         0         0
# 송파구              0         1         0
# 양천구              2         0         0
# 영등포구             0         0         0
# 용산구             49         1         0
# 은평구              0         0         0
# 종로구              3         0         0
# 중구               0         0         1
# 중랑구              0         0         0

# %%
plt.figure(figsize=(20,18))
sns.heatmap(sellcount, annot=True, fmt="d", linewidths=.5)

# %%
# Out:
#        건축년도  거래년도  거래월  거래일자    법정동   거래금액       아파트이름   전용면적   지역코드   층  \
# 10     1995  2019    1     4   명륜2가  73500         아남1  84.80  11110   2
# 11     1995  2019    1     6   명륜2가  85000         아남1  84.90  11110  17
# 32     2001  2019    1    23    평창동  57500       롯데낙천대  84.21  11110   5
# 39     2002  2019    2    16   명륜1가  59500        아마레스  84.59  11110   4
# 40     1995  2019    2    28   명륜2가  74800         아남1  84.90  11110   2
# ...     ...   ...  ...   ...    ...    ...         ...    ...    ...  ..
# 68854  1998  2019   12    19    천호동  51700       성원아파트  83.15  11740   6
# 68858  1985  2019   12    27    천호동  78000          우성  84.93  11740   1
# 68860  2009  2019   12     7    강일동  79750  강일리버파크10단지  84.53  11740   9
# 68861  2009  2019   12     9    강일동  77800   강일리버파크2단지  84.74  11740   4
# 68862  2009  2019   12    25    강일동  80000   강일리버파크7단지  84.83  11740   3
#
#          지번  전용면적(평)  전용면적(평)2  전용면적(평)3 시군구명   평단가
# 10        4    25.65        25  (20, 25]  종로구  2865
# 11        4    25.68        25  (20, 25]  종로구  3309
# 32       72    25.47        25  (20, 25]  종로구  2257
# 39     45-5    25.59        25  (20, 25]  종로구  2325
# 40        4    25.68        25  (20, 25]  종로구  2912
# ...     ...      ...       ...       ...  ...   ...
# 68854   564    25.15        25  (20, 25]  강동구  2055
# 68858  19-1    25.69        25  (20, 25]  강동구  3036
# 68860   695    25.57        25  (20, 25]  강동구  3118
# 68861   668    25.63        25  (20, 25]  강동구  3035
# 68862   686    25.66        25  (20, 25]  강동구  3117
#
# [26620 rows x 16 columns]

# %%
tmp.plot(x='전용면적(평)3',y='평단가')

# %% [markdown]
# ### 거래량

# %% [markdown]
# #### 평수별 거래량

# %%
#평수별 거래량
fin.pivot_table(values='전용면적(평)',index='전용면적(평)3',aggfunc='count')
# Out:
#           전용면적(평)
# 전용면적(평)3
# (0, 5]       1615
# (5, 10]      2137
# (10, 15]     6596
# (15, 20]    19211
# (20, 25]    26620
# (25, 30]     2052
# (30, 35]     4854
# (35, 40]     2740
# (40, 45]     1296
# (45, 50]      863
# (50, 55]      317
# (55, 60]      182
# (60, 65]      144
# (65, 70]       98
# (70, 75]      123
# (75, 80]       12
# (80, 85]        4

# %% [markdown]
# #### 평수별 거래비율

# %%
sell = ((fin.pivot_table(values='전용면적(평)',index='전용면적(평)3',aggfunc='count')/fin.count())*100)
sell[['전용면적(평)']]
# Out:
#             전용면적(평)
# 전용면적(평)3
# (0, 5]     2.345202
# (5, 10]    3.103218
# (10, 15]   9.578299
# (15, 20]  27.897014
# (20, 25]  38.655901
# (25, 30]   2.979786
# (30, 35]   7.048676
# (35, 40]   3.978857
# (40, 45]   1.881970
# (45, 50]   1.253195
# (50, 55]   0.460328
# (55, 60]   0.264289
# (60, 65]   0.209108
# (65, 70]   0.142309
# (70, 75]   0.178613
# (75, 80]   0.017426
# (80, 85]   0.005809

# %% [markdown]
# #### 지역별 거래량

# %%
fin.groupby(by='시군구명')[['거래일자']].count()
# Out:
#       거래일자
# 시군구명
# 강남구   4344
# 강동구   3786
# 강북구   1192
# 강서구   3323
# 관악구   2128
# 광진구   1621
# 구로구   3304
# 금천구   1432
# 노원구   6658
# 도봉구   2722
# 동대문구  2510
# 동작구   2421
# 마포구   2624
# 서대문구  2376
# 서초구   2947
# 성동구   2988
# 성북구   3464
# 송파구   5395
# 양천구   3590
# 영등포구  2872
# 용산구   1378
# 은평구   2147
# 종로구    571
# 중구     914
# 중랑구   2157

# %% [markdown]
# #### 지역별 거래비율

# %%
disp = ((fin.pivot_table(values='전용면적(평)',index='시군구명',aggfunc='count')/fin.count())*100)[['전용면적(평)']]
disp
# Out:
#        전용면적(평)
# 시군구명
# 강남구   6.308086
# 강동구   5.497793
# 강북구   1.730948
# 강서구   4.825453
# 관악구   3.090149
# 광진구   2.353915
# 구로구   4.797862
# 금천구   2.079461
# 노원구   9.668332
# 도봉구   3.952718
# 동대문구  3.644865
# 동작구   3.515625
# 마포구   3.810409
# 서대문구  3.450279
# 서초구   4.279449
# 성동구   4.338987
# 성북구   5.030204
# 송파구   7.834282
# 양천구   5.213174
# 영등포구  4.170539
# 용산구   2.001046
# 은평구   3.117739
# 종로구   0.829171
# 중구    1.327254
# 중랑구   3.132261

# %% [markdown]
# #### 구별 거래량, 그중 최고비율구에서는 거래된 평수의 비율이 어떤지

# %%
no = fin[fin['시군구명']=='노원구']
# Out:
#   File "<ipython-input-122-9c32e9482a80>", line 3
#     no.pivot_table(values='전용면적(평)',index='전용면적(평)3',aggfunc='count')/no.count())*100)
#                                                                                 ^
# SyntaxError: invalid syntax

# %%
# make figure and assign axis objects
fig = plt.figure(figsize=(15, 10))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
fig.subplots_adjust(wspace=0)

# pie chart parameters
# rotate so that first wedge is split by the x-axis
angle = -180 * ratios[0]
ax1.pie(disp.loc[:,'전용면적(평)'], autopct='%1.1f%%', startangle=angle,
        labels=disp.index)

xpos = 0
width = .2
bottom = 0

for j in range(len(disp.loc[:,'전용면적(평)'])):
    height = sell.[j]
    ax2.bar(xpos, height, width, bottom=bottom)
    ypos = bottom + ax2.patches[j].get_height() / 2
    bottom += height
    ax2.text(xpos, ypos, "%d%%" % (ax2.patches[j].get_height() * 100),
             ha='center')

ax2.set_title('거래된 평수의 비율')
ax2.legend(sell.index)
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)
# Out:
# (-0.5, 0.5)

# %% [markdown]
# #### 건축년도별 거래량

# %%
fin.pivot_table(values='전용면적(평)',index='건축년도',aggfunc='count')
# Out:
#       전용면적(평)
# 건축년도
# 1961        1
# 1965        1
# 1966        5
# 1968       16
# 1969       35
# 1970       41
# 1971      128
# 1972       27
# 1973       27
# 1974      156
# 1975      143
# 1976      179
# 1977      167
# 1978      460
# 1979      345
# 1980      320
# 1981      219
# 1982      437
# 1983      628
# 1984      595
# 1985      594
# 1986     1352
# 1987     1441
# 1988     3678
# 1989     1383
# 1990      836
# 1991      994
# 1992     1653
# 1993     1623
# 1994     1192
# 1995     1666
# 1996     1865
# 1997     2408
# 1998     2456
# 1999     3528
# 2000     3310
# 2001     2291
# 2002     2173
# 2003     3489
# 2004     3639
# 2005     2556
# 2006     1983
# 2007     1750
# 2008     2532
# 2009     1496
# 2010     1326
# 2011     1594
# 2012     1349
# 2013     1327
# 2014     1824
# 2015     1092
# 2016     1634
# 2017      967
# 2018      928
# 2019     1005

# %% [markdown]
# #### 건축년도별 거래비율

# %%
((fin.pivot_table(values='전용면적(평)',index='건축년도',aggfunc='count')/fin.count())*100)[['전용면적(평)']]
# Out:
#        전용면적(평)
# 건축년도
# 1961  0.001452
# 1965  0.001452
# 1966  0.007261
# 1968  0.023234
# 1969  0.050825
# 1970  0.059538
# 1971  0.185874
# 1972  0.039208
# 1973  0.039208
# 1974  0.226533
# 1975  0.207656
# 1976  0.259933
# 1977  0.242507
# 1978  0.667983
# 1979  0.500987
# 1980  0.464684
# 1981  0.318018
# 1982  0.634584
# 1983  0.911942
# 1984  0.864022
# 1985  0.862570
# 1986  1.963290
# 1987  2.092530
# 1988  5.340962
# 1989  2.008306
# 1990  1.213987
# 1991  1.443425
# 1992  2.400383
# 1993  2.356819
# 1994  1.730948
# 1995  2.419261
# 1996  2.708237
# 1997  3.496747
# 1998  3.566450
# 1999  5.123141
# 2000  4.806575
# 2001  3.326847
# 2002  3.155495
# 2003  5.066508
# 2004  5.284329
# 2005  3.711664
# 2006  2.879589
# 2007  2.541241
# 2008  3.676812
# 2009  2.172398
# 2010  1.925534
# 2011  2.314707
# 2012  1.958934
# 2013  1.926987
# 2014  2.648699
# 2015  1.585734
# 2016  2.372793
# 2017  1.404217
# 2018  1.347584
# 2019  1.459398

# %% [markdown]
# ## 5. 시각화
# #### 시각화 그래프는 7개 이상 나와야 합니다.
#     - 각각의 그래프마다 분석에 있어서 세웠던 전략과 시각화 목적을 간단한 코멘트를 달아주세요
# #### 수업시간에 언급하지 않은 새로운 패턴의 그래프는 3개 이상 사용하시기 바랍니다.
#     - 그래프에 대한 간단한 설명과 함께 코멘트로 직접 달아주세요

# %% [markdown]
# #### 작업시간은 오후 3시까지 생각하고 있습니다.
#     - 최종 발표시간은 4시입니다.
